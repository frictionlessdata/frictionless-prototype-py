# %% [markdown]
# # Validating Data

# %% [markdown]
# ## Validate functions

# %% [markdown]
# ### Validating Schema

# %% [markdown]
# ### Validating Resource

# %% [markdown]
# ### Validating Package

# %% [markdown]
# ### Validating Inquiry

# %% [markdown]
# ### Validating Table
